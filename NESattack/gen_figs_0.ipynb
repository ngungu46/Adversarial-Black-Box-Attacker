# %%
import os 
import matplotlib.pyplot as plt 
import json 
from pprint import pprint  


stats = [os.path.join("outputs", "run_0", fpath) for fpath in os.listdir(os.path.join("outputs", "run_0")) if fpath.endswith(".json")]

# %%
queries = []

for stat in stats: 
    with open(stat) as f: 
        data = json.load(f) 
        # pprint(data)
        
        if data["status"] == "SUCCESS": 
            queries.append(data["num_queries_needed"])

# %%
plt.hist(queries)
plt.xlabel("Number of Queries")
plt.ylabel("Count")
# plt.title("")
# Out:
# (array([15., 29.,  9., 17., 12.,  9.,  2.,  1.,  1.,  2.]),
#  array([  400.,  2330.,  4260.,  6190.,  8120., 10050., 11980., 13910.,
#         15840., 17770., 19700.]),
#  <BarContainer object of 10 artists>)
